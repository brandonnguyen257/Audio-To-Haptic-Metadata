# %%
# %matplotlib inline
from utils.haptic_utils import *
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import Audio

# %%
#Define constants
TEST_AUDIO_PATH = "test_audio_files/"

file_name = "Heat Waves.mp3" #change this to the name of the song you want to test

# %%
file_location = 'sunSala.mp3'
audio_time_series , audio_samplerate = librosa.load(file_location)

# %%
# Plot the waveform
plt.figure(figsize=(30, 10))
librosa.display.waveshow(audio_time_series, sr=audio_samplerate)
plt.show()
