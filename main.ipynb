# %%
# %matplotlib inline
from utils.haptic_utils import *
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import Audio

# %%
#Define constants
TEST_AUDIO_PATH = "test_audio_files/"

file_name = "Heat Waves.mp3" #change this to the name of the song you want to test

# %%
file_location = 'sunSala.mp3'
audio_time_series , audio_samplerate = librosa.load(file_location)

# %%
count = np.sum(audio_time_series > 0.5)

print("Number of samples where value is greater than 0.5:", count)
duration = len(audio_time_series) / audio_samplerate

print(f"{len(audio_time_series)=}")
print(f"{audio_samplerate=}")
print(f"{duration=}")

# Plot the waveform
plt.figure(figsize=(30, 10))
plt.plot(audio_time_series)
plt.title('Audio waveform ' + file_location)
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.show()
# Out:
# Number of samples where value is greater than 0.5: 318315
# len(audio_time_series)=4245504
# audio_samplerate=22050
# duration=192.53986394557822
